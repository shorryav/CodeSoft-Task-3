# %% [markdown]
# #IRIS FLOWER ANALYSIS
# The Iris flower data set is a multivariate data set introduced by the British statistician and biologist Ronald Fisher in his 1936 paper The use of multiple measurements in taxonomic problems. It is sometimes called Anderson's Iris data set because Edgar Anderson collected the data to quantify the morphologic variation of Iris flowers of three related species. The data set consists of 50 samples from each of three species of Iris (Iris Setosa, Iris virginica, and Iris versicolor). Four features were measured from each sample: the length and the width of the sepals and petals, in centimeters.
#
# This dataset became a typical test case for many statistical classification techniques in machine learning such as support vector machines

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/IRIS.csv')

# %%
data.head(60)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width          species
# 0            5.1          3.5           1.4          0.2      Iris-setosa
# 1            4.9          3.0           1.4          0.2      Iris-setosa
# 2            4.7          3.2           1.3          0.2      Iris-setosa
# 3            4.6          3.1           1.5          0.2      Iris-setosa
# 4            5.0          3.6           1.4          0.2      Iris-setosa
# 5            5.4          3.9           1.7          0.4      Iris-setosa
# 6            4.6          3.4           1.4          0.3      Iris-setosa
# 7            5.0          3.4           1.5          0.2      Iris-setosa
# 8            4.4          2.9           1.4          0.2      Iris-setosa
# 9            4.9          3.1           1.5          0.1      Iris-setosa
# 10           5.4          3.7           1.5          0.2      Iris-setosa
# 11           4.8          3.4           1.6          0.2      Iris-setosa
# ...

# %%
data.shape
# Out:
# (150, 5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
data.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
#Count of all Iris Species
plt.figure(figsize=(10,6))
sns.countplot(data['species'], color = '#5A4FCF')
plt.title("Count of Iris Species")
plt.xlabel("Species")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# #Distribution of Iris Feature

# %%
#Create Histogram of 'sepal_length' feature
plt.figure(figsize = (11,6))
plt.hist(data = data, x = 'sepal_length', color = '#5A4FCF', edgecolor = 'linen', bins = 5 )
plt.title(label = 'Distribution of Sepal Length')
plt.xlabel("Sepal Length")
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **Observations**
#
# - We observe that the histogram is normally distributed.
#
# - The maximum count of values for sepal length lies in between 5.75 to 6.5

# %%
#calculating the mean of sepal_length
round(data['sepal_length'].mean(),2)
# Out:
# 5.84

# %%
#medain of sepal_length
data['sepal_length'].median()
# Out:
# 5.8

# %%
# Create a histogram of the "sepal_length" feature and also show the mean and the median

plt.figure(figsize = (11,6))
sns.histplot(data = data, x = 'sepal_length', color = '#5A4FCF')
plt.title("histogram of sepal_length")
plt.xlabel('Sepal Length')
plt.ylabel('Count')
plt.vlines(data['sepal_length'].mean(), ymin = 0, ymax = 30, color = 'green', linestyle = '--', label = 'Mean')
plt.vlines(data['sepal_length'].median(), ymin = 0, ymax = 30, color = 'red', linestyle = '--', label = 'Median')
plt.legend()
plt.show()

# %% [markdown]
# **observation**
#
# - We have seen that mean and median are clear represntative of data
#
# - Mean and median are very close to each other
#
# - We can choose either mean or median as the measure of central tendency

# %%
#creating a histogram of 'sepal_width' feature

plt.figure(figsize = (11,6))
plt.hist(data = data, x = 'sepal_width', color = '#5A4FCF', edgecolor = 'linen', bins = 5 )
plt.title(label = 'Distribution of Sepal Width')
plt.xlabel("Sepal Width")
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize = (11,6))
sns.distplot(data['sepal_width'], color = '#5A4FCF')
plt.title("Distribution of Petal Length")
plt.xlabel("Petal Length")
plt.ylabel('Count')
plt.show()
# Out:
# <ipython-input-46-8c0fdd1e580d>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['sepal_width'], color = '#5A4FCF')

# %% [markdown]
# **Observation**
#
# - We have observe that histogram is normally distributed
#
# - The maximum count of values of sepal width lies between 2.9 to 3.8

# %%
# Calculating mean
round(data['sepal_width'].mean(),2)
# Out:
# 3.05

# %%
# Calculating Median

data['sepal_width'].median()
# Out:
# 3.0

# %%
# Plotting mean and median for sepal width

plt.figure(figsize = (11,6))
sns.histplot(data = data, x = 'sepal_width', color = '#5A4FCF')
plt.title("histogram of sepal_width")
plt.xlabel('Sepal Width')
plt.ylabel('Count')
plt.vlines(data['sepal_width'].mean(), ymin = 0, ymax = 40, color = 'green', linestyle = '--', label = 'Mean')
plt.vlines(data['sepal_width'].median(), ymin = 0, ymax = 40, color = 'red', linestyle = '--', label = 'Median')
plt.legend()
plt.show()

# %% [markdown]
# **Observation**
#
# - We have seen that mean and median is close to each other
# - We can choose either mean or median for measure of central tendency

# %%
# Create Histogram of petal length

plt.figure(figsize = (11,6))
plt.hist(data = data, x = 'petal_length', color = '#5A4FCF', edgecolor = 'linen', bins = 5 )
plt.title(label = 'Distribution of Petal Length')
plt.xlabel("Petal Length")
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **Observation**
#
# - We have observe that the histogram is not equally distributed
# - As we have seen skewness, therefore we can check the distribution using distplot function.

# %%
# plot displot for petal length

plt.figure(figsize = (11,6))
sns.distplot(data['petal_length'], color = '#5A4FCF')
plt.title("Distribution of Petal Length")
plt.xlabel("Petal Length")
plt.ylabel('Count')
plt.show()
# Out:
# <ipython-input-44-e8d75056920c>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['petal_length'], color = '#5A4FCF')

# %%
data['petal_length'].skew()
# Out:
# -0.27446425247378287

# %%
# create histogram of petal width

plt.figure(figsize = (11,6))
plt.hist(data = data, x = 'petal_width', color = '#5A4FCF', edgecolor = 'linen', bins = 5 )
plt.title(label = 'Distribution of Petal Width')
plt.xlabel("Petal Width")
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize = (11,6))
sns.distplot(data['petal_width'], color = '#5A4FCF')
plt.title("Distribution of Petal Width")
plt.xlabel("Petal Width")
plt.ylabel('Count')
plt.show()
# Out:
# <ipython-input-52-92d00ee855da>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['petal_width'], color = '#5A4FCF')

# %%
data['petal_width'].skew()
# Out:
# -0.10499656214412734

# %%
# correlation between sepal_length Vs sepal_width

plt.figure(figsize = (11,6))
plt.scatter(data['sepal_length'], data['sepal_width'], color = 'red', alpha = 0.7)
plt.title("Sepal Length Vs Sepal Width")
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.grid(True)
plt.show()

# %%
# Correlation Between petal length Vs Petal Width

plt.figure(figsize = (11,6))
plt.scatter(data['petal_length'], data['petal_width'])
plt.title("Relationship Between Petal Length Vs Petal Width")
plt.xlabel("Petal Length")
plt.ylabel("Petal Width")
plt.grid(True)
plt.show()

# %%
# Correlation Between sepal_length Vs Petal_Length

plt.figure(figsize = (11,6))
plt.scatter(data['sepal_length'], data['petal_length'], color = 'red', alpha = 0.7)
plt.title("Sepal Length Vs Petal Length")
plt.xlabel("Sepal Length")
plt.ylabel("Petal Length")
plt.grid(True)
plt.show()

# %%
# Correlation between sepal_width Vs petaL_width

plt.figure(figsize = (11,6))
plt.scatter(data['sepal_width'], data['petal_width'], color = 'red', alpha = 0.7)
plt.title("Sepal Width Vs Petal Width")
plt.xlabel("Sepal Width")
plt.ylabel("Petal Width")
plt.grid(True)

# %%
iris_setosa = data[data['species'] == 'Iris-setosa'].sum()
iris_setosa
# Out:
# sepal_length                                                250.3
# sepal_width                                                 170.9
# petal_length                                                 73.2
# petal_width                                                  12.2
# species         Iris-setosaIris-setosaIris-setosaIris-setosaIr...
# dtype: object

# %%
Iris_versicolor = data[data['species']=='Iris-versicolor'].sum()
Iris_versicolor
# Out:
# sepal_length                                                296.8
# sepal_width                                                 138.5
# petal_length                                                213.0
# petal_width                                                  66.3
# species         Iris-versicolorIris-versicolorIris-versicolorI...
# dtype: object

# %%
Iris_virginica = data[data['species']=='Iris-virginica'].sum()
Iris_virginica
# Out:
# sepal_length                                                329.4
# sepal_width                                                 148.7
# petal_length                                                277.6
# petal_width                                                 101.3
# species         Iris-virginicaIris-virginicaIris-virginicaIris...
# dtype: object

# %%
sum_of_Species = data.groupby('species').sum()
sum_of_Species
# Out:
#                  sepal_length  sepal_width  petal_length  petal_width
# species
# Iris-setosa             250.3        170.9          73.2         12.2
# Iris-versicolor         296.8        138.5         213.0         66.3
# Iris-virginica          329.4        148.7         277.6        101.3

# %%
sum_of_Species.plot(kind = 'bar', figsize = (11,6))
plt.title("Sum of Species")
plt.xlabel("Species")
plt.ylabel("Count")
plt.show()
